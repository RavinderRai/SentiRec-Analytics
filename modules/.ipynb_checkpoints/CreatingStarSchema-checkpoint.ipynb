# %% [markdown]
# # Creating Star Schema
#
# This notebook is used to load all the relevant csv files and transform them to create a Star schema, and then load them into a local database to help stay organized. The sentiment csv files will be used to start the fact table. The ratingScore from the amazon_reviews and amazon_US_reviews will be moved into the fact table as well.
#
# Note: the yt_reviews and yt_reviews_v2 are redundant when we have the yt_reviews_gen_summaries csv file, so we don't need them. The SoundGuys csv files were used to fine-tune a model, so they can be left out of the database for now.

# %%
import pandas as pd
import ast

# %%
US_sentiments = pd.read_csv('US_sentiments.csv')
cad_sentiments = pd.read_csv('cad_sentiments.csv')
yt_reviews_gen_summaries = pd.read_csv('yt_reviews_gen_summaries.csv')
amazon_US_reviews = pd.read_csv('amazon_US_reviews.csv')
amazon_reviews = pd.read_csv('amazon_reviews.csv')
amazon_product_descriptions = pd.read_csv('amazon_product_descriptions.csv')
averaged_embeddings = pd.read_csv('averaged_embeddings.csv')

# %% [markdown]
# Add regions to the sentiments datasets.

# %%
US_sentiments['region'] = 'US'
cad_sentiments['region'] = 'CAD'

# %%
US_sentiments.shape
# Out:
# (729, 10)

# %% [markdown]
# Now let's do any cleaning needed for the review datasets and also remove the relevant numeric columns and put them in the sentiments datasets instead. These new sentiments datasets when combined will be the facts table.

# %%
amazon_US_reviews.shape
# Out:
# (729, 20)

# %%
amazon_US_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729 entries, 0 to 728
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ratingScore           729 non-null    float64
#  1   reviewTitle           729 non-null    object
#  2   reviewUrl             679 non-null    object
#  3   reviewReaction        494 non-null    object
#  4   reviewedIn            729 non-null    object
#  5   date                  729 non-null    object
#  6   country               729 non-null    object
#  7   countryCode           0 non-null      float64
#  8   reviewDescription     729 non-null    object
#  9   isVerified            729 non-null    bool
#  10  variant               650 non-null    object
#  11  reviewImages          729 non-null    object
#  12  position              729 non-null    float64
#  13  productAsin           729 non-null    object
#  14  reviewCategoryUrl     729 non-null    object
#  15  totalCategoryRatings  729 non-null    float64
#  16  totalCategoryReviews  729 non-null    float64
#  17  filterByRating        729 non-null    object
#  18  product               729 non-null    object
#  19  headphoneName         729 non-null    object
# dtypes: bool(1), float64(5), object(14)
# memory usage: 109.0+ KB

# %%
test_review = amazon_US_reviews['product'][0]
test_review
# Out:
# "{'price': {'value': 164.97, 'currency': '$'}, 'listPrice': None}"

# %%
def extract_individual_values(dct, value_type):
    """
    helper function to handle none values
    """
    try:
        return dct.get(value_type)
    except:
        return None
    
def extract_values(row):
    """
    takes the product column and expands it to get all values in their own column
    
    Input: 
    row - the row of the dataframe to iterate on
    
    Output:
    a one row dataframe with 4 columns
    """
    try:
        json_data = ast.literal_eval(row)
        price_data = json_data.get('price', {})
        list_price_data = json_data.get('listPrice', {})
    
        return pd.Series({
            'priceValue': extract_individual_values(price_data, 'value'),
            'priceCurrency': extract_individual_values(price_data, 'currency'),
            'listPriceValue': extract_individual_values(list_price_data, 'value'),
            'listPriceCurrency': extract_individual_values(list_price_data, 'currency')
        })
    except:
        return pd.Series({
            'priceValue': None,
            'priceCurrency': None,
            'listPriceValue': None,
            'listPriceCurrency': None
        })

# %%
extract_values(amazon_US_reviews['product'][455])
# Out:
# priceValue           113.85
# priceCurrency             $
# listPriceValue       151.68
# listPriceCurrency         $
# dtype: object

# %%
amazon_US_reviews_product = amazon_US_reviews['product'].apply(lambda x: extract_values(x))
amazon_US_reviews_product['priceCurrency'] = 'USD'
amazon_US_reviews_product['listPriceCurrency'] = 'USD'
amazon_US_reviews_product
# Out:
#      priceValue priceCurrency  listPriceValue listPriceCurrency
# 0        164.97           USD             NaN               USD
# 1        164.97           USD             NaN               USD
# 2        164.97           USD             NaN               USD
# 3        164.97           USD             NaN               USD
# 4        164.97           USD             NaN               USD
# ..          ...           ...             ...               ...
# 724      129.99           USD             NaN               USD
# 725      129.99           USD             NaN               USD
# 726      129.99           USD             NaN               USD
# 727      129.99           USD             NaN               USD
# 728      129.99           USD             NaN               USD
#
# [729 rows x 4 columns]

# %%
cleaned_amazon_US_reviews = pd.concat([amazon_US_reviews, amazon_US_reviews_product], axis = 1)
cleaned_amazon_US_reviews.head(2)
# Out:
#    ratingScore                                        reviewTitle  \
# 0          1.0      Possibly worth the trouble for half the price
# 1          1.0  TLDR Warning !  But if you going to spend this...
#
#                                            reviewUrl  \
# 0  https://www.amazon.com/gp/customer-reviews/R3U...
# 1  https://www.amazon.com/gp/customer-reviews/ROP...
#
#                   reviewReaction  \
# 0   15 people found this helpful
# 1  401 people found this helpful
#
#                                           reviewedIn        date  \
# 0  Reviewed in the United States on October 26, 2021  2021-10-26
# 1  Reviewed in the United States on December 7, 2021  2021-12-07
#
#          country  countryCode  \
# 0  United States          NaN
# 1  United States          NaN
#
#                                    reviewDescription  isVerified  ...  \
# 0  This is the 3rd, & last, set of recently purch...        True  ...
# 1  UPDATE IV:.After several months with many othe...        True  ...
#
#                                    reviewCategoryUrl totalCategoryRatings  \
# 0  https://www.amazon.com/product-reviews/B094C4V...               2085.0
# 1  https://www.amazon.com/product-reviews/B094C4V...               2085.0
#
#    totalCategoryReviews filterByRating  \
# 0                1354.0        oneStar
# 1                1354.0        oneStar
#
#                                              product     headphoneName  \
# 0  {'price': {'value': 164.97, 'currency': '$'}, ...  sony xm4 earbuds
# 1  {'price': {'value': 164.97, 'currency': '$'}, ...  sony xm4 earbuds
#
#    priceValue priceCurrency listPriceValue listPriceCurrency
# 0      164.97           USD            NaN               USD
# 1      164.97           USD            NaN               USD
#
# [2 rows x 24 columns]

# %%
#now turning the above into a function so we can repeat it
def expand_product_col(amazon_reviews, currency):
    amazon_reviews_product = amazon_reviews['product'].apply(lambda x: extract_values(x))
    #canadian currency has the same symbol as US so let's change them
    amazon_reviews_product['priceCurrency'] = currency
    amazon_reviews_product['listPriceCurrency'] = currency
    
    cleaned_amazon_reviews_product = pd.concat([amazon_reviews, amazon_reviews_product], axis = 1)
    return cleaned_amazon_reviews_product

cleaned_amazon_US_reviews = expand_product_col(amazon_US_reviews, 'USD').head()
cleaned_amazon_CAD_reviews = expand_product_col(amazon_reviews, 'CAD').head()

# %%
numeric_amazon_US_reviews = cleaned_amazon_US_reviews[['ratingScore', 'priceValue', 'priceCurrency', 'listPriceValue', 'listPriceCurrency']]
numeric_amazon_US_reviews.head()
# Out:
#    ratingScore  priceValue priceCurrency  listPriceValue listPriceCurrency
# 0          1.0      164.97           USD             NaN               USD
# 1          1.0      164.97           USD             NaN               USD
# 2          1.0      164.97           USD             NaN               USD
# 3          1.0      164.97           USD             NaN               USD
# 4          1.0      164.97           USD             NaN               USD

# %% [markdown]
# ## Generating Fact Table

# %%
pd.concat([US_sentiments, numeric_amazon_US_reviews], axis=1)
# Out:
#         headphoneName batteryLabel  batteryScore comfortLabel  comfortScore  \
# 0    sony xm4 earbuds     Negative      0.894016     Negative      0.886814
# 1    sony xm4 earbuds     Positive      0.908510     Positive      0.916273
# 2    sony xm4 earbuds     Negative      0.499079          NaN      0.000000
# 3    sony xm4 earbuds     Negative      0.867483          NaN      0.000000
# 4    sony xm4 earbuds     Negative      0.885287          NaN      0.000000
# ..                ...          ...           ...          ...           ...
# 724       lg tone tf8          NaN      0.000000          NaN      0.000000
# 725       lg tone tf8          NaN      0.000000          NaN      0.000000
# 726       lg tone tf8          NaN      0.000000          NaN      0.000000
# 727       lg tone tf8          NaN      0.000000          NaN      0.000000
# 728       lg tone tf8          NaN      0.000000          NaN      0.000000
#
#     noisecancellationLabel  noisecancellationScore soundqualityLabel  \
# 0                      NaN                0.000000               NaN
# 1                      NaN                0.000000          Positive
# 2                 Negative                0.517302               NaN
# 3                 Negative                0.843609               NaN
# 4                 Negative                0.832005          Negative
# ..                     ...                     ...               ...
# 724               Negative                0.992355               NaN
# 725                    NaN                0.000000               NaN
# 726                    NaN                0.000000               NaN
# 727                    NaN                0.000000               NaN
# 728                    NaN                0.000000               NaN
#
#      soundqualityScore region  ratingScore  priceValue priceCurrency  \
# 0             0.000000     US          1.0      164.97           USD
# 1             0.908909     US          1.0      164.97           USD
# 2             0.000000     US          1.0      164.97           USD
# 3             0.000000     US          1.0      164.97           USD
# 4             0.846645     US          1.0      164.97           USD
# ..                 ...    ...          ...         ...           ...
# 724           0.000000     US          3.0      129.99           USD
# 725           0.000000     US          3.0      129.99           USD
# 726           0.000000     US          3.0      129.99           USD
# 727           0.000000     US          2.0      129.99           USD
# 728           0.000000     US          2.0      129.99           USD
#
#      listPriceValue listPriceCurrency
# 0               NaN               USD
# 1               NaN               USD
# 2               NaN               USD
# 3               NaN               USD
# 4               NaN               USD
# ..              ...               ...
# 724             NaN               USD
# 725             NaN               USD
# 726             NaN               USD
# 727             NaN               USD
# 728             NaN               USD
#
# [729 rows x 15 columns]

# %%
def get_fact_table_by_region(df_sentiments, cleaned_amazon_reviews):
    numeric_amazon_reviews = cleaned_amazon_reviews[['ratingScore', 'priceValue', 'priceCurrency', 'listPriceValue', 'listPriceCurrency']]
    fact_table_region = pd.concat([df_sentiments, numeric_amazon_reviews], axis=1)
    
    return fact_table_region

# %%
US_fact_table = get_fact_table_by_region(US_sentiments, cleaned_amazon_US_reviews)
CAD_fact_table = get_fact_table_by_region(cad_sentiments, cleaned_amazon_CAD_reviews)

# %%
fact_table = pd.concat([US_fact_table, CAD_fact_table], axis=0)
assert CAD_fact_table.shape[0] + US_fact_table.shape[0] == fact_table.shape[0]

# %%
fact_table.head(2)
# Out:
#       headphoneName batteryLabel  batteryScore comfortLabel  comfortScore  \
# 0  sony xm4 earbuds     Negative      0.894016     Negative      0.886814
# 1  sony xm4 earbuds     Positive      0.908510     Positive      0.916273
#
#   noisecancellationLabel  noisecancellationScore soundqualityLabel  \
# 0                    NaN                     0.0               NaN
# 1                    NaN                     0.0          Positive
#
#    soundqualityScore region  ratingScore  priceValue priceCurrency  \
# 0           0.000000     US          1.0      164.97           USD
# 1           0.908909     US          1.0      164.97           USD
#
#    listPriceValue listPriceCurrency
# 0             NaN               USD
# 1             NaN               USD

# %%
fact_table['primary_key'] = range(1, len(fact_table) + 1)
fact_table = fact_table[[
        'primary_key', 'region', 'ratingScore',
        'priceValue', 'priceCurrency', 'listPriceValue', 'listPriceCurrency', 
        'headphoneName', 'batteryLabel', 'batteryScore', 'comfortLabel',
        'comfortScore', 'noisecancellationLabel', 'noisecancellationScore',
        'soundqualityLabel', 'soundqualityScore'
]]
fact_table.head()
# Out:
#    primary_key region  ratingScore  priceValue priceCurrency  listPriceValue  \
# 0            1     US          1.0      164.97           USD             NaN
# 1            2     US          1.0      164.97           USD             NaN
# 2            3     US          1.0      164.97           USD             NaN
# 3            4     US          1.0      164.97           USD             NaN
# 4            5     US          1.0      164.97           USD             NaN
#
#   listPriceCurrency     headphoneName batteryLabel  batteryScore comfortLabel  \
# 0               USD  sony xm4 earbuds     Negative      0.894016     Negative
# 1               USD  sony xm4 earbuds     Positive      0.908510     Positive
# 2               USD  sony xm4 earbuds     Negative      0.499079          NaN
# 3               USD  sony xm4 earbuds     Negative      0.867483          NaN
# 4               USD  sony xm4 earbuds     Negative      0.885287          NaN
#
#    comfortScore noisecancellationLabel  noisecancellationScore  \
# 0      0.886814                    NaN                0.000000
# 1      0.916273                    NaN                0.000000
# 2      0.000000               Negative                0.517302
# 3      0.000000               Negative                0.843609
# 4      0.000000               Negative                0.832005
#
#   soundqualityLabel  soundqualityScore
# 0               NaN           0.000000
# 1          Positive           0.908909
# 2               NaN           0.000000
# 3               NaN           0.000000
# 4          Negative           0.846645

# %% [markdown]
# ## Cleaning amazon_product_descriptions
#
# Next we need to clean the amazon_product_descriptions csv file. Aside from that, the yt_reviews_gen_summaries and averaged_embeddings csv files are fine as is.

# %%
amazon_product_descriptions['Product_Attributes'][0]
# Out:
# "[['title', 'url', 'asin', 'inStock', 'inStockText', 'brand', 'author', 'price', 'listPrice', 'shippingPrice', 'stars', 'starsBreakdown', 'reviewsCount', 'answeredQuestions', 'breadCrumbs', 'thumbnailImage', 'galleryThumbnails', 'highResolutionImages', 'description', 'features', 'attributes', 'productOverview', 'variantAsins', 'variantDetails', 'reviewsLink', 'hasReviews', 'delivery', 'fastestDelivery', 'returnPolicy', 'support', 'variantAttributes', 'manufacturerAttributes', 'seller', 'bestsellerRanks', 'isAmazonChoice', 'amazonChoiceText', 'bookDescription', 'locationText', 'loadedCountryCode', 'unNormalizedProductUrl']]"

# %%
amazon_product_descriptions['Product_Descriptions'][0]
# Out:
# "[['Sony WF-1000XM4 Industry Leading Noise Canceling Truly Wireless Earbud Headphones with Alexa Built-in, Black', 'https://www.amazon.ca/dp/B094C4VDJZ', 'B094C4VDJZ', True, 'Only 5 left in stock.', 'Sony', None, {'value': 289.99, 'currency': '$'}, None, None, 4.1, {'5star': 0.61, '4star': 0.16, '3star': 0.08, '2star': 0.05, '1star': 0.11}, 23438, None, 'Electronics › Headphones, Earbuds & Accessories › Headphones', 'https://m.media-amazon.com/images/I/41d-Q1ehHdL.__AC_SX300_SY300_QL70_ML2_.jpg', ['https://m.media-amazon.com/images/I/21nysGNCVpL._AC_US.jpg', 'https://m.media-amazon.com/images/I/21nDwMxVqOL._AC_US.jpg', 'https://m.media-amazon.com/images/I/21fLmR3fnuL._AC_US.jpg', 'https://m.media-amazon.com/images/I/21-CJIF3vFL._AC_US.jpg', 'https://m.media-amazon.com/images/I/2131AoNzYtL._AC_US.jpg', 'https://m.media-amazon.com/images/I/21TVkuTARrL._AC_US.jpg', 'https://m.media-amazon.com/images/I/11M2RWeiS3L._AC_US.jpg'], ['https://m.media-amazon.com/images/I/41d-Q1ehHdL._AC_SL1500_.jpg', 'https://m.media-amazon.com/images/I/41uFaHZVrCL._AC_SL1500_.jpg', 'https://m.media-amazon.com/images/I/41urRmWgQCL._AC_SL1500_.jpg', 'https://m.media-amazon.com/images/I/61J1KcEV5ZL._AC_SL1500_.jpg', 'https://m.media-amazon.com/images/I/41BFrPk-AqL._AC_SL1500_.jpg', 'https://m.media-amazon.com/images/I/41TTDR5D0QL._AC_SL1500_.jpg', 'https://m.media-amazon.com/images/I/31CltYo2NeL._AC_SL1500_.jpg', 'https://m.media-amazon.com/images/I/514PFpzgd1L._AC_SL1500_.jpg', 'https://m.media-amazon.com/images/I/71eEB7eH2KL._AC_SL1500_.jpg'], 'TRUE WIRELESS EARBUDS, NOISE-CANCELING, ALEXA BUILTIN, IPX42', ['Industry-leading noise canceling bluetooth earbuds with the new Integrated Processor V1', 'Note:If you face issue in Bluetooth connectivity please turn off the Bluetooth function for a couple of minutes, then turn it back on', 'Exceptional sound quality with new Integrated Processor V1 and supporting LDAC codec. High power neodymium magnets', 'Crystal-clear call quality, beamforming microphone and a bone-conduction sensor provide clear voice detection even in noisy environments', 'Speak-to-chat technology automatically reduces volume during conversations', '8 hours long battery with Noise Canceling. Frequency Response(Bluetooth Communication)-20Hz - 20,000Hz(44.1kHz sampling) / 20Hz - 40,000Hz(LDAC 96kHz sampling, 990kbps). Bluetooth Profile A2DP, AVRCP, HFP, HSP'], [{'key': 'Brand', 'value': ''}, {'key': 'Manufacturer', 'value': ''}, {'key': 'Place of Business', 'value': ''}, {'key': 'Model', 'value': ''}, {'key': 'Model Name', 'value': ''}, {'key': 'Model year', 'value': ''}, {'key': 'Part Number', 'value': ''}, {'key': 'Special features', 'value': ''}, {'key': 'Mounting Hardware', 'value': ''}, {'key': 'Number of Items', 'value': ''}, {'key': 'Microphone format', 'value': ''}, {'key': 'Headphones Form Factor', 'value': ''}, {'key': 'Charging Time', 'value': ''}, {'key': 'Batteries included', 'value': ''}, {'key': 'Batteries Required', 'value': ''}, {'key': 'Battery Cell Composition', 'value': ''}, {'key': 'Cable Feature', 'value': ''}, {'key': 'Connector Type', 'value': ''}, {'key': 'Material Type', 'value': ''}, {'key': 'Form Factor', 'value': ''}, {'key': 'Does it contain liquid?', 'value': ''}, {'key': 'Includes rechargable battery', 'value': ''}, {'key': 'Manufacturer', 'value': ''}, {'key': 'Item model number', 'value': ''}, {'key': 'Product Dimensions', 'value': ''}, {'key': 'ASIN', 'value': ''}, {'key': 'Batteries', 'value': '1 Lithium Ion batteries required. (included)'}, {'key': 'Date First Available', 'value': 'May 13 2021'}, {'key': 'Is discontinued by manufacturer', 'value': 'No'}], [{'key': 'Brand', 'value': 'Sony'}, {'key': 'Model name', 'value': 'WF1000XM4/B'}, {'key': 'Colour', 'value': 'Black'}, {'key': 'Form factor', 'value': 'In Ear'}, {'key': 'Connectivity technology', 'value': 'Bluetooth 5.2'}], ['B094C4VDJZ', 'B094CLC7WK'], [{'asin': 'B094CLC7WK', 'name': 'Silver', 'thumbnail': 'https://m.media-amazon.com/images/I/21v4igWo-U ...
